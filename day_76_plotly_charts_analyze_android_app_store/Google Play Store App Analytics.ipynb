# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv("apps.csv")

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.sample(5)
# Out:
#                                                     App      Category  Rating  \
# 159                                          Ambient CX      BUSINESS     NaN
# 3055   Convert degree Celsius to Fahrenheit or °F to °C         TOOLS    4.40
# 3533                      Mix Tank – Tank Mixing Ag App  PRODUCTIVITY    3.60
# 10738                                          Snapchat        SOCIAL    4.00
# 9521                        Order & Chaos 2: 3D MMO RPG        FAMILY    4.10
#
#         Reviews  Size_MBs     Installs  Type Price Content_Rating  \
# 159           0      7.50            5  Free     0       Everyone
# 3055         51      2.10        5,000  Free     0       Everyone
# 3533         64     15.00       10,000  Free     0       Everyone
# 10738  17000166      5.30  500,000,000  Free     0           Teen
# 9521     242722     54.00   10,000,000  Free     0           Teen
#
#              Genres      Last_Updated         Android_Ver
# ...

# %%
df_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size_MBs        10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content_Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last_Updated    10841 non-null  object
#  11  Android_Ver     10839 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1016.5+ KB

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(["Last_Updated", "Android_Ver"], axis=1, inplace=True)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps
# Out:
#                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME    4.50
# 10837                                Subway Surfers             GAME    4.50
# 10838                                Subway Surfers             GAME    4.50
# 10839                                Subway Surfers             GAME    4.50
# 10840                                Subway Surfers             GAME    4.50
#
# ...

# %%
df_apps.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
df_apps_clean = df_apps.dropna().copy()
df_apps_clean
# Out:
#                                                    App Category  Rating  \
# 21                                 KBA-EZ Health Guide  MEDICAL    5.00
# 28                                            Ra Ga Ba     GAME    5.00
# 47                                             Mu.F.O.     GAME    5.00
# 82                                    Brick Breaker BR     GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00
# ...                                                ...      ...     ...
# 10836                                   Subway Surfers     GAME    4.50
# 10837                                   Subway Surfers     GAME    4.50
# 10838                                   Subway Surfers     GAME    4.50
# 10839                                   Subway Surfers     GAME    4.50
# 10840                                   Subway Surfers     GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating   Genres
# ...

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().sum()
# Out:
# np.int64(476)

# %%
mask = df_apps_clean["App"]=="Instagram"
df_apps_clean[mask]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps_clean.drop_duplicates(inplace=True)

# %%
df_apps_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
mask = df_apps_clean["App"]=="Instagram"
df_apps_clean[mask]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10810     0           Teen  Social

# %%
dp_mask = df_apps_clean["App"].duplicated()
duplicated_indicies = df_apps_clean[dp_mask].index
df_apps_clean.drop(duplicated_indicies, inplace=True)

# %%
df_apps_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_apps_clean["App"].duplicated().sum()
# Out:
# np.int64(0)

# %%
mask = df_apps_clean["App"]=="Instagram"
df_apps_clean[mask]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8197 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8197 non-null   object
#  1   Category        8197 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         8197 non-null   int64
#  4   Size_MBs        8197 non-null   float64
#  5   Installs        8197 non-null   object
#  6   Type            8197 non-null   object
#  7   Price           8197 non-null   object
#  8   Content_Rating  8197 non-null   object
#  9   Genres          8197 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.4+ KB

# %% [markdown]
# * We do need to convert `["Installs", "Price"]` columns type to integer & float respectively.

# %%
df_apps_clean.sort_values(
    by=["Rating", "Installs", "Reviews"],
    ascending=False
)
# Out:
#                                    App             Category  Rating  Reviews  \
# 1789                           Ek Vote         PRODUCTIVITY    5.00       43
# 1499        Trinity Church Deltona, FL            LIFESTYLE    5.00       33
# 1556             Catholic La Bu Zo Kam  BOOKS_AND_REFERENCE    5.00       23
# 1550         Comunidad De Fe Minitries            LIFESTYLE    5.00       19
# 1552              Dr. ES PV Calculator                TOOLS    5.00       19
# ...                                ...                  ...     ...      ...
# 240            House party - live chat               DATING    1.00        1
# 357                  Speech Therapy: F               FAMILY    1.00        1
# 1932    FE Mechanical Engineering Prep               FAMILY    1.00        2
# 2449              Tech CU Card Manager              FINANCE    1.00        2
# 2416  BJ Bridge Standard American 2018                 GAME    1.00        1
#
# ...

# %%
# Convert `Installs` column to integer
df_apps_clean["Installs"] = df_apps_clean["Installs"].apply(
    lambda x: int(x.replace(",", ""))
)

# %%
# Convert `Installs` column to integer
df_apps_clean["Price"] = df_apps_clean["Price"].apply(
    lambda x: float(x.replace("$", ""))
)

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8197 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8197 non-null   object
#  1   Category        8197 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         8197 non-null   int64
#  4   Size_MBs        8197 non-null   float64
#  5   Installs        8197 non-null   int64
#  6   Type            8197 non-null   object
#  7   Price           8197 non-null   float64
#  8   Content_Rating  8197 non-null   object
#  9   Genres          8197 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 704.4+ KB

# %%
df_apps_clean.sort_values(
    by=["Rating", "Installs", "Reviews"],
    ascending=False
)
# Out:
#                                                    App   Category  Rating  \
# 4058                          Ek Bander Ne Kholi Dukan     FAMILY    5.00
# 3115                                        Oración CX  LIFESTYLE    5.00
# 2750  Superheroes, Marvel, DC, Comics, TV, Movies News     COMICS    5.00
# 3030           CL Keyboard - Myanmar Keyboard (No Ads)      TOOLS    5.00
# 2095                                        Ríos de Fe  LIFESTYLE    5.00
# ...                                                ...        ...     ...
# 576                                      Clarksburg AH    MEDICAL    1.00
# 617                                     DT future1 cam      TOOLS    1.00
# 728                      Truck Driving Test Class 3 BC     FAMILY    1.00
# 240                            House party - live chat     DATING    1.00
# 357                                  Speech Therapy: F     FAMILY    1.00
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating         Genres
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values(by="Size_MBs", ascending=False).head()
# Out:
#                                 App Category  Rating  Reviews  Size_MBs  \
# 9943          Miami crime simulator     GAME    4.00   254518    100.00
# 9945                Ultimate Tennis   SPORTS    4.30   183004    100.00
# 9944   Gangster Town: Vice District   FAMILY    4.30    65146    100.00
# 10687        Hungry Shark Evolution     GAME    4.50  6074334    100.00
# 10295               SimCity BuildIt   FAMILY    4.50  4218587    100.00
#
#         Installs  Type  Price Content_Rating      Genres
# 9943    10000000  Free   0.00     Mature 17+      Action
# 9945    10000000  Free   0.00       Everyone      Sports
# 9944    10000000  Free   0.00     Mature 17+  Simulation
# 10687  100000000  Free   0.00           Teen      Arcade
# 10295   50000000  Free   0.00   Everyone 10+  Simulation

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values(by="Reviews", ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 10805  78158306      5.30  1000000000  Free   0.00           Teen
# 10785  69119316      3.50  1000000000  Free   0.00       Everyone
# 10806  66577313      5.30  1000000000  Free   0.00           Teen
# 10784  56642847      3.50  1000000000  Free   0.00       Everyone
# 10650  44891723     98.00   100000000  Free   0.00   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# 10650       Strategy

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean["Content_Rating"].value_counts().copy()
ratings
# Out:
# Content_Rating
# Everyone           6619
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values)
fig.show()

# %%
fig = px.pie(
    labels=ratings.index,
    values=ratings.values,
    title="Content Rating",
    names=ratings.index,
)
fig.update_traces(textposition="outside", textinfo="percent+label")
fig.show()

# %%
fig = px.pie(
    labels=ratings.index,
    values=ratings.values,
    title="Content Rating",
    names=ratings.index,
    hole=0.6,
)
fig.update_traces(textposition="inside", textinfo="percent", textfont_size=15)
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
over_billion_installs = df_apps_clean[df_apps_clean["Installs"] >= 1_000_000_000]
print(len(over_billion_installs), "apps had over 1 billion installations.")
# Out:
# 20 apps had over 1 billion installations.

# %%
single_installs = df_apps_clean[df_apps_clean["Installs"] < 2]
print(len(single_installs), "apps had only a single installations.")
# Out:
# 3 apps had only a single installations.

# %%
df_apps_clean[["Installs"]].describe().T
# Out:
#             count         mean           std  min       25%        50%  \
# Installs 8,197.00 9,159,349.32 58,247,709.98 1.00 10,000.00 100,000.00
#
#                   75%              max
# Installs 1,000,000.00 1,000,000,000.00

# %%
df_apps_clean["Installs"].value_counts().sort_values(ascending=False)
# alternatively
# df_apps_clean[["App", "Installs"]].groupby("Installs").count()
# Out:
# Installs
# 1000000       1417
# 100000        1095
# 10000          988
# 10000000       933
# 1000           698
# 5000000        607
# 500000         504
# 50000          457
# 5000           425
# 100            303
# 50000000       202
# 500            199
# 100000000      188
# 10              69
# 50              56
# 500000000       24
# 1000000000      20
# 5                9
# 1                3
# Name: count, dtype: int64

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.sort_values("Price", ascending=False).head(20)
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# ...

# %% [markdown]
# ### The most expensive apps sub $250

# %%
most_expensive_apps = df_apps_clean[df_apps_clean["Price"] >= 250].copy()
most_expensive_apps
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2193             I am extremely Rich  LIFESTYLE    2.90       41      2.90
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 3856                   I am rich VIP  LIFESTYLE    3.80      411      2.60
# ...

# %%
df_apps_clean.drop(most_expensive_apps.index, inplace=True)

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %% [markdown]
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean["Revenue_Estimate"] = df_apps_clean["Installs"] * df_apps_clean["Price"]
df_apps_clean
# Out:
#                                                    App            Category  \
# 21                                 KBA-EZ Health Guide             MEDICAL
# 28                                            Ra Ga Ba                GAME
# 47                                             Mu.F.O.                GAME
# 82                                    Brick Breaker BR                GAME
# 99     Anatomy & Physiology Vocabulary Exam Review App             MEDICAL
# ...                                                ...                 ...
# 10824                                     Google Drive        PRODUCTIVITY
# 10828                                          YouTube       VIDEO_PLAYERS
# 10829                          Google Play Movies & TV       VIDEO_PLAYERS
# 10831                                      Google News  NEWS_AND_MAGAZINES
# 10835                                   Subway Surfers                GAME
#
# ...

# %%
df_apps_clean.sort_values("Revenue_Estimate", ascending=False).head(10)
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 7477            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 6082                   Weather Live      WEATHER    4.50    76593      4.75
# 6746     Card Wars - Adventure Time       FAMILY    4.30   129603     23.00
# 7954                    Bloons TD 5       FAMILY    4.60   190086     94.00
# 7044                         Tasker        TOOLS    4.60    43045      3.40
#
#       Installs  Type  Price Content_Rating                     Genres  \
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean["Category"].nunique()
# Out:
# 33

# %%
df_apps_clean["Category"].value_counts().head(10)
# Out:
# Category
# FAMILY             1606
# GAME                910
# TOOLS               718
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             291
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: count, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
top10_category = df_apps_clean["Category"].value_counts().copy()[:10]

bar = px.bar(x=top10_category.index, y=top10_category.values)
bar.show()

# %%
category_installs = df_apps_clean.groupby("Category").agg({"Installs": pd.Series.sum})
category_installs.sort_values("Installs", inplace=True)
category_installs.head(10)
# Out:
#                      Installs
# Category
# EVENTS               15949410
# BEAUTY               26916200
# PARENTING            31116110
# MEDICAL              39062676
# COMICS               44931100
# LIBRARIES_AND_DEMO   52083000
# AUTO_AND_VEHICLES    53129800
# HOUSE_AND_HOME       97082000
# ART_AND_DESIGN      114233100
# DATING              140912410

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
h_bar = px.bar(
    x=category_installs["Installs"],
    y=category_installs.index,
    orientation="h",
    title="Category Popularity",
    width=1100,
    height=900,
)
h_bar.update_layout(xaxis_title="Number of Downloads", yaxis_title="Category")
h_bar.show()

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
categories_installs_apps = df_apps_clean.groupby("Category").agg(
    {"Installs": pd.Series.sum, "App": pd.Series.count}
)
categories_installs_apps.sort_values(
    by=["Installs", "App"], ascending=False, inplace=True
)
categories_installs_apps.head(10)
# Out:
#                        Installs   App
# Category
# GAME                13858762717   910
# COMMUNICATION       11039241530   257
# TOOLS                7999724500   718
# PRODUCTIVITY         5788070180   301
# SOCIAL               5487841475   203
# PHOTOGRAPHY          4649143130   263
# FAMILY               4437554490  1606
# VIDEO_PLAYERS        3916897200   148
# TRAVEL_AND_LOCAL     2894859300   187
# NEWS_AND_MAGAZINES   2369110650   204

# %%
scatter_fig = px.scatter(
    data_frame=categories_installs_apps,
    x="App",
    y="Installs",
    color="Installs",
    size="App",
    hover_name=categories_installs_apps.index,
    width=950,
    height=500,
    log_y=True,
)
scatter_fig.update_layout(
    xaxis_title="Number of Apps (Lower = More Conctentrated)",
    yaxis_title="Installs",
    # yaxis=dict(type="log")
)
scatter_fig.show()

# %% [markdown]
# What we see is that the categories like Family, Tools, and Game have many different apps sharing a high number of downloads. But for the categories like video players and entertainment, all the downloads are concentrated in very few apps.
#
# ![image.png](attachment:c9888475-eb1b-43e4-bac8-b9f98d500b65.png)

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean["Genres"].value_counts()
# Out:
# Genres
# Tools                       717
# Entertainment               467
# Education                   429
# Productivity                301
# Personalization             298
#                            ...
# Casual;Music & Video          1
# Tools;Education               1
# Role Playing;Brain Games      1
# Adventure;Education           1
# Lifestyle;Pretend Play        1
# Name: count, Length: 114, dtype: int64

# %%
stack = df_apps_clean["Genres"].str.split(";", expand=True).stack()
stack
# Out:
# 21     0                    Medical
# 28     0                     Arcade
# 47     0                     Arcade
# 82     0                     Arcade
# 99     0                    Medical
#                      ...
# 10824  0               Productivity
# 10828  0    Video Players & Editors
# 10829  0    Video Players & Editors
# 10831  0           News & Magazines
# 10835  0                     Arcade
# Length: 8562, dtype: object

# %%
num_genres = stack.value_counts()
num_genres
# Out:
# Tools                      718
# Education                  587
# Entertainment              498
# Action                     304
# Productivity               301
# Personalization            298
# Lifestyle                  298
# Finance                    296
# Medical                    291
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# ...

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar_fig = px.bar(
    title="Top Genres",
    x=num_genres[:15].index,
    y=num_genres[:15],
    hover_name=num_genres.index[:15],
    color=num_genres[:15],
    color_continuous_scale="Agsunset",
    width=800,
    height=470
)
bar_fig.update_layout(
    xaxis_title="Genre",
    yaxis_title="Number of Apps",
    coloraxis_showscale=False
)
bar_fig.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({"App": pd.Series.count})
df_free_vs_paid.sort_values("App")
# Out:
#               Category  Type   App
# 3    AUTO_AND_VEHICLES  Paid     1
# 17       ENTERTAINMENT  Paid     2
# 24      FOOD_AND_DRINK  Paid     2
# 38  NEWS_AND_MAGAZINES  Paid     2
# 48            SHOPPING  Paid     2
# ..                 ...   ...   ...
# 31           LIFESTYLE  Free   284
# 21             FINANCE  Free   289
# 53               TOOLS  Free   655
# 25                GAME  Free   834
# 19              FAMILY  Free  1456
#
# [61 rows x 3 columns]

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
df_free_vs_paid.sample()
# Out:
#      Category  Type  App
# 40  PARENTING  Paid    2

# %%
bar_fig = px.bar(
    # data_frame=df_free_vs_paid.sort_values("App", ascending=False),
    data_frame=df_free_vs_paid,
    x="Category",
    y="App",
    color="Type",
    barmode="group",
    # log_y=True,
    title="Free vs Paid Apps by Category",
    width=850,
    height=500,
)
bar_fig.update_layout(
    xaxis_title="Category",
    yaxis_title="Number of Apps",
    xaxis={"categoryorder": "total descending"},
    yaxis={"type": "log"},
)
# bar_fig.update_xaxes(categoryorder="total descending")
bar_fig.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box_fig = px.box(
    data_frame=df_apps_clean,
    x="Type",
    y="Installs",
    color="Type",
    notched=True,
    points="all",
    title="How Many Downloads are Paid Apps Giving Up?",
    width=800,
    height=600,
)
box_fig.update_layout(
    yaxis={"type": "log"},
)
box_fig.show()

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used `'min ascending'` to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean["Type"]=="Paid"]

box_fig = px.box(
    data_frame=df_paid_apps,
    x="Category",
    y="Revenue_Estimate",
    title="How Much Can Paid Apps Earn?",
    width=900,
    height=500,
)
box_fig.update_layout(
    yaxis_title="Paid App Ballpark Revenue",
    xaxis={"categoryorder": "min ascending"},
    yaxis={"type": "log"},
)
box_fig.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
print(f'The median price for an Android app: ${df_paid_apps["Price"].median()}')
# Out:
# The median price for an Android app: $2.99

# %%
box_fig = px.box(
    data_frame=df_paid_apps,
    x="Category",
    y="Price",
    title="Price per Category",
    width=900,
    height=500,
)
box_fig.update_layout(
    xaxis={"categoryorder": "max descending"},
    yaxis={"type": "log"},
    yaxis_title="Paid App Price",
)
box_fig.show()
